# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# %env twitter_api_key
# Out:
# 'pFlQlVe3RxDDloIFv3Wq3lv2I'

# %%
# engine = parte das análises (apenas) -> jogar um x ou xyx dados e receber um resultado quanto é considerado robô
# API = vou enviar um perfil > vou converter? > dados e jogar no engine <> api <> devolve pra quem pediu
# site (www.pegabot.com.br)
# pegabot lote (analises.pegabot.com.br)
# API do pegabot: https://backend.pegabot.com.br/botometer?profile=blckjzz&search_for=profile

# %%
import tweepy

# Loading variables

twitter = {}
twitter['TWITTER_API_KEY'] = %env twitter_api_key 
twitter['TWITTER_API_SECRET'] = %env twitter_api_secret
twitter['TWITTER_API_TOKEN'] = %env twitter_access_token
twitter['TWITTER_API_TOKEN_SECRET'] = %env twitter_access_token_secret


#for key in twitter:
#    print(key, '->', twitter[key])

# Authenticate with Twitter API

twitter['TWITTER_API_TOKEN_SECRET']
auth = tweepy.OAuthHandler(twitter['TWITTER_API_KEY'], twitter['TWITTER_API_SECRET'])

# se não autenticar com o access token algumas funcionalidades da api 
# não ficam disponíveis. tipo verificar rate limits.
auth.set_access_token(twitter['TWITTER_API_TOKEN'], twitter['TWITTER_API_TOKEN_SECRET'])

# o objeto api é utilizado para realizar toda comunicação com a API do twitter.
api = tweepy.API(auth)

# %%
# recuperando dados de um twitter user
try:
    user = api.get_user('blckjzz'); 
    print("##############")
    print(user.id_str) # recover user twitter_id
    print(user.name) # prints the name of the user
    print(user.screen_name) # prints the username (@ of the user)
    print(user.followers_count) # 
    print(user.friends_count) # 
    print(user.created_at)
    print(user.verified)
    print("##############")
except tweepy.TweepError as e:
        print("Tweepy Error: {}".format(e))
# Out:
# ##############
# 1080370887357071362
# Diego Cerqueira
# blckjzz
# 298
# 365
# 2019-01-02 07:51:06
# False
# ##############

# %%
# recuperar os X tweets de um perfil
tweets = api.user_timeline(user_id=1080370887357071362, count=100);

for tweet in tweets:
    print("printing the x latests tweets from: " + str(tweet.author.name))
    print(
        str(tweet.id)              + " - " + 
        str(tweet.text)            + " - " + 
        str(tweet.author.name)     + " - " +
        str("É um retweet? [")     + 
            str(tweet.is_quote_status) + 
        str("]")
        )
# Out:
# printing the x latests tweets from: Diego Cerqueira
# 1438561915597467651 - Saiu também uma matéria escrita pela @camposmello sobre o mesmo relatório
#
# https://t.co/hCVT5LjqQH - Diego Cerqueira - É um retweet? [False]
# printing the x latests tweets from: Diego Cerqueira
# 1438561454530207756 - Fresquinho! Saiu a pesquisa em parceria com a @RSF_pt monitorou ataques à imprensa em 2021, usando o
# @pegabots do… https://t.co/tRP8ldcIwc - Diego Cerqueira - É um retweet? [True]
# printing the x latests tweets from: Diego Cerqueira
# 1436098048296370179 - @yaso @RosieDaSerenata @cuducos @NataliaMazotte @teomoura2 Ótima notícia! Espero que ajude nossos robôs cívicos a n… https://t.co/rmZyRR4sdl - Diego Cerqueira - É um retweet? [False]
# printing the x latests tweets from: Diego Cerqueira
# 1436097861003972608 - Boas novidades para os robôs do bem do Twitter!
#
# @pegabots https://t.co/p5V5WaFAkh - Diego Cerqueira - É um retweet? [True]
# printing the x latests tweets from: Diego Cerqueira
# 1436033000517607427 - RT @CodingRights: Que felicidade ver @ninadhora e @fecampa na Comissão de Transparência das Eleições do TSE. Tarefa fundamental em tempos d… - Diego Cerqueira - É um retweet? [False]
# printing the x latests tweets from: Diego Cerqueira
# 1436031585833390086 - @ninadhora Que incrível, @ninadhora!! Você é muito incrível. Fico feliz em ter conhecido você, inspiração total. Vo… https://t.co/1eE0pyEGNh - Diego Cerqueira - É um retweet? [False]
# printing the x latests tweets from: Diego Cerqueira
# 
Diego Cerqueira - É um retweet? [True]
# printing the x latests tweets from: Diego Cerqueira
# 1364606022694879236 - Venci na vida: https://t.co/xL0WknUUS7 - Diego Cerqueira - É um retweet? [True]
# printing the x latests tweets from: Diego Cerqueira
# 1364605945561645056 - @tarciziosilva @SueliCarneiro @samadeu @passalanorh @gomarigomes @dantasglends @pblnns @silvanabahia @flamedeirosss… https://t.co/McFN6opBUx - Diego Cerqueira - É um retweet? [False]

# %%
user = api.followers(screen_name="jairbolsonaro", count=20)
for seguidor in user:
    print(seguidor.name + " - " + str(seguidor.created_at))

# %%
# verifica os rate limites da chave em utilização
rateLimits = api.rate_limit_status()
rateLimits['resources']

# %%
trends = api.trends_available()

trendsBR = api.trends_place(23424768)

# recupera as trends do br com o código
# retorna um json (ver como navegar nele)
# -> trend > name > conteudo

# %%
# Verify twitter credentials 
authUser = api.verify_credentials()
authUser
# Out:
# User(_api=<tweepy.api.API object at 0x111563190>, _json={'id': 1080370887357071362, 'id_str': '1080370887357071362', 'name': 'Diego Cerqueira', 'screen_name': 'blckjzz', 'location': '', 'description': 'Pesquisador - Tecnologias Cívicas - Engenharia de Software | @itsriodejaneiro • Eu estudo internet e crio tecnologias para pagar boletos', 'url': 'https://t.co/pHhO41f9g7', 'entities': {'url': {'urls': [{'url': 'https://t.co/pHhO41f9g7', 'expanded_url': 'https://linktr.ee/blckjzz', 'display_url': 'linktr.ee/blckjzz', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 298, 'friends_count': 365, 'listed_count': 7, 'created_at': 'Wed Jan 02 07:51:06 +0000 2019', 'favourites_count': 685, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 263, 'lang': None, 'status': {'created_at': 'Thu Sep 16 17:54:22 +0000 2021', 'id': 1438561915597467651, 'id_str': '1438561915597467651', 'text': 'Saiu também uma matéria escrita pela @camposmello sobre o mesmo relatório\n\nhttps://t.co/hCVT5LjqQH', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'camposmello', 'name': 'Patricia Campos Mello', 'id': 36714704, 'id_str': '36714704', 'indices': [37, 49]}], 'urls': [{'url': 'https://t.co/hCVT5LjqQH', 'expanded_url': 'https://www1.folha.uol.com.br/poder/2021/09/estudo-aponta-meio-milhao-de-tuites-ofensivos-a-imprensa-em-tres-meses-no-brasil.shtml', 'display_url': 'www1.folha.uol.com.br/poder/2021/09/…', 'indices': [75, 98]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1438561454530207756, 'in_reply_to_status_id_str': '1438561454530207756', 'in_reply_to_user_id': 1080370887357071362, 'in_reply_to_user_id_str': '1080370887357071362', 'in_reply_to_screen_name': 'blckjzz', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'pt'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1434130081522360320/rP67tPnL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1434130081522360320/rP67tPnL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080370887357071362/1630076495', 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [], 'suspended': False, 'needs_phone_verification': False}, id=1080370887357071362, id_str='1080370887357071362', name='Diego Cerqueira', screen_name='blckjzz', location='', description='Pesquisador - Tecnologias Cívicas - Engenharia de Software | @itsriodejaneiro • Eu estudo internet e crio tecnologias para pagar boletos', url='https://t.co/pHhO41f9g7', entities={'url': {'urls': [{'url': 'https://t.co/pHhO41f9g7', 'expanded_url': 'https://linktr.ee/blckjzz', 'display_url': 'linktr.ee/blckjzz', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=298, friends_count=365, listed_count=7, created_at=datetime.datetime(2019, 1, 2, 7, 51, 6), favourites_count=685, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=263, lang=None, status=Status(_api=<tweepy.api.API object at 0x111563190>, _json={' ...

# %%
rateLimits = api.rate_limit_status()
rateLimits
# Out:
# {'rate_limit_context': {'access_token': '1080370887357071362-WliGiLV7sQ1JZENHzO1ZVCcV4QxRHs'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631828625},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631828625},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631828625},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631828625},
#    '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631828625},
#    '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631828625},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631828625}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'verify': {'/verify/:version/badge-violation': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/badge-violation/violations': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/intake': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/document-formats': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/id-document&GET': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/verify/:version/id-document&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/access': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/verify/:version/account-eligibility': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'admin_users': {'/admin_users': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1631828625}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1631828625},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1631828625}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1631828625},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1631828625}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'compliance': {'/compliance/jobs&POST': {'limit': 150,
#     'remaining': 150,
#     'reset': 1631828625},
#    '/compliance/jobs&GET': {'limit': 150,
#     'remaining': 150,
#     'reset': 1631828625},
#    '/compliance/jobs/:job_id': {'limit': 150,
#     'remaining': 150,
#     'reset': 1631828625}},
#   'paseto': {'/paseto/token': {'limit': 25,
#     'remaining': 25,
#     'reset': 1631828625}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1631828625},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1631828625},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:id': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:id/muting&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/:source_user_id/blocking/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1631828625},
#    '/users/:id/followed_lists': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:source_user_id/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:id/retweets/:source_tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:id/likes&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/users/:id/pinned_lists': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1631828625},
#    '/users/:id/retweets&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/by/username/:handle/tweets': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/:id/blocking&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/by/username/:source_username/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/users/:id/muting': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/:id/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/by/username/:username': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/users/by/username/:username/followers': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:id/blocking': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/users/:id/likes/:tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/by/username/:username/following': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/users/by/username/:handle/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/users/:source_user_id/muting/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/users/:id/liked_tweets': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625}},
#   'teams': {'/teams/authorize': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625}},
#   'permissions': {'/permissions/user_permissions/admin_email_verification': {'limit': 3,
#     'remaining': 3,
#     'reset': 1631828625},
#    '/permissions/user_permissions': {'limit': 3,
#     'remaining': 3,
#     'reset': 1631828625}},
#   'tweets&POST': {'/tweets&POST': {'limit': 200,
#     'remaining': 200,
#     'reset': 1631828625}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1631828625},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631828625}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1631828625},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625}},
#   'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#     'remaining': 5,
#     'reset': 1631828625},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/labs/:version/users/:id/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1631828625},
#    '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1631828625},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1631828625},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/labs/:version/tweets/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/labs/:version/users/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/labs/:version/tweets/stream/compliance': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1631828625}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1631828625},
#    '/moments/create': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1631828625}},
#   'fleets': {'/fleets/:version/mutes/create': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/viewers': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/fleets/:version/avatar_content': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/fleets/:version/fleetline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/track_events': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/update': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/fleets/:version/fleet_threads': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/fleets/:version/mutes/list': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/mutes/destroy': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1631828625},
#    '/fleets/:version/feedback/create': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625}},
#   'graphql&POST': {'/graphql&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1631828625},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1631828625},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1631828625},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1631828625},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1631828625},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1631828625},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1631828625},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#     'remaining': 150,
#     'reset': 1631828625}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1631828625},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 74,
#     'reset': 1631828566},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1631828625},
#    '/account/change_password': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1631828625}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'tweets': {'/tweets/search/all': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/tweets/search/stream/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/tweets/search/recent': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625},
#    '/tweets/sample/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/tweets/:id&DELETE': {'limit': 50, 'remaining': 50, 'reset': 1631828625},
#    '/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/tweets/counts/all': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/tweets/search/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1631828625},
#    '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/tweets/:id/retweeted_by': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/tweets/:tweet_id/liking_users': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1631828625},
#    '/tweets/search/stream/rules&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/tweets/counts/recent': {'limit': 900,
#     'remaining': 900,
#     'reset': 1631828625},
#    '/tweets/search/stream/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/tweets/:id/hidden&PUT': {'limit': 50,
#     'remaining': 50,
#     'reset': 1631828625}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}},
#   'oauth': {'/oauth/revoke': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625},
#    '/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1631828625},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1631828625}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1631828625},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1631828625},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1631828625}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1631828625}},
#   'graphql': {'/graphql': {'limit': 15,
#     'remaining': 15,
#     'reset': 1631828625}}}}

# %%
for i in rateLimits['resources']:
    print(rateLimits['resources']['lists'])
# Out:
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
# {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/:id/members': {'limit': 300, 'remaining': 300, 'reset': 1631809962}, '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631809962}, '/lists/subscribers/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631809962}, '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631809962}, '/lists': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/:id': {'limit': 50, 'remaining': 50, 'reset': 1631809962}, '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631809962}, '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631809962}}
